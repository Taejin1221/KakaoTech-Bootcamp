# %% [markdown]
# # Data Download

# %%
# !kaggle datasets download -d dansbecker/food-101
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dansbecker/food-101
# License(s): other
# Downloading food-101.zip to /home/ec2-user/KakaoTech-Bootcamp/Team Project
# 100%|█████████████████████████████████████▉| 9.38G/9.38G [06:15<00:00, 29.6MB/s]
# 100%|██████████████████████████████████████| 9.38G/9.38G [06:15<00:00, 26.8MB/s]

# %%
# !unzip -qq food-101.zip -d Data/

# %% [markdown]
# # Load modules and Set constans

# %%
import os, cv2, glob, datetime

import numpy as np
import matplotlib.pyplot as plt

# %%
EXPERIMENT_DATA = {
    'name' : 'Korean_Food_Classification',
    'number' : '2',
    'description' : [
        'Food 101 데이터를 통한 전이학습 결과 확인',
        'ImageNet으로 학습 된 MobileNet 모델 사용'
    ]
}

ROOT_DIR = os.getcwd()

# Data directory
DATA_DIR = os.path.join(ROOT_DIR, 'Data', 'food-101', 'food-101', 'images')

# Result directory
RESULT_DIR = os.path.join(ROOT_DIR, 'Results')
if ('Results' not in os.listdir(ROOT_DIR)):
    os.mkdir('Results')

os.chdir(RESULT_DIR)
curr_result_dir_name = f'{EXPERIMENT_DATA["name"]}_{EXPERIMENT_DATA["number"]}'
if (curr_result_dir_name not in os.listdir()):
    os.mkdir(curr_result_dir_name)
CURR_RESULT_DIR = os.path.join(RESULT_DIR, curr_result_dir_name)

# %%
NUM_CLASS = 10
BATCH_SIZE = 512
EPOCHS = 10

TRAIN_RATIO = 0.9
TEST_RATIO = 0.1

# %%
os.chdir(CURR_RESULT_DIR)
with open('README.md', 'wt') as file:
    file.write('# Description of current experiment\n')
    file.write(f'- {curr_result_dir_name}\n')
    for desc in EXPERIMENT_DATA['description']:
        file.write(f'- {desc}\n')
    file.write('\n')

    file.write('# Experiment environment\n')
    file.write('- AWS Environment\n')
    file.write('- Instance type: g4dn.2xlarge')
    file.write('- GPU: NVIDIA T4')

# %% [markdown]
# # Load and preprocess data

# %%
def img_read(file):
    img = cv2.cvtColor(cv2.imread(file, cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB)
    return cv2.resize(img, dsize=(224, 224), interpolation=cv2.INTER_LINEAR)

# %%
os.chdir(DATA_DIR)

data_list = sorted(os.listdir())
if data_list[0] == '.DS_Store':
    data_list = data_list[1:]

food_numbers = { }
x_train, x_test, y_train, y_test = [], [], [], []
for categoryIdx, category in enumerate(data_list[:NUM_CLASS]):
    os.chdir(category)
    food_numbers[categoryIdx] = category

    file_names = sorted(glob.glob('*.jpg'))
    number_of_files = len(file_names)

    # Load Train Data
    print(f'{categoryIdx}/{NUM_CLASS} {category}\ntrain: {int(number_of_files * TRAIN_RATIO)}개', end = ' ')
    before = datetime.datetime.now()
    for file in file_names[:int(number_of_files * TRAIN_RATIO)]:
        x_train.append(img_read(file))
        y_train.append(categoryIdx)
    time_diff = datetime.datetime.now() - before
    print(f'{time_diff.seconds}s')

    # Load Test Data
    print(f'test: {int(number_of_files * TEST_RATIO)}개', end = ' ')
    before = datetime.datetime.now()
    for file in file_names[int(number_of_files * TRAIN_RATIO):]:
        x_test.append(img_read(file))
        y_test.append(categoryIdx)
    time_diff = datetime.datetime.now() - before
    print(f'{time_diff.seconds}s')

    os.chdir('..')
# Out:
# 0/10 apple_pie
# train: 900개 2s
# test: 100개 0s
# 1/10 baby_back_ribs
# train: 900개 2s
# test: 100개 0s
# 2/10 baklava
# train: 900개 2s
# test: 100개 0s
# 3/10 beef_carpaccio
# train: 900개 2s
# test: 100개 0s
# 4/10 beef_tartare
# train: 900개 2s
# test: 100개 0s
# 5/10 beet_salad
# train: 900개 2s
# test: 100개 0s
# 6/10 beignets
# train: 900개 2s
# test: 100개 0s
# 7/10 bibimbap
# train: 900개 2s
# test: 100개 0s
# 8/10 bread_pudding
# train: 900개 2s
# test: 100개 0s
# 9/10 breakfast_burrito
# train: 900개 2s
# test: 100개 0s

# %%
fig, ax = plt.subplots(1, 3, sharey=True, figsize=(60, 20))
for axIdx, dataIdx in enumerate([0, 900, 1800]):
    ax[axIdx].imshow(x_train[dataIdx])
    ax[axIdx].set_title(food_numbers[y_train[dataIdx]], fontsize=30)
plt.show()

# %%
x_train, y_train = np.array(x_train), np.array(y_train)
x_test, y_test = np.array(x_test), np.array(y_test)
x_train, x_test = x_train.astype('float32') / 255., x_test.astype('float32') / 255.

# %%
print(f'Train data: ({x_train.shape}, {y_train.shape})')
print(f'Test data: ({x_test.shape}, {y_test.shape})')
# Out:
# Train data: ((9000, 224, 224, 3), (9000,))
# Test data: ((1000, 224, 224, 3), (1000,))

# %% [markdown]
# # Model Building

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
y_train, y_test = keras.utils.to_categorical(y_train, NUM_CLASS), keras.utils.to_categorical(y_test, NUM_CLASS)

# %%
mobile = keras.applications.MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
x = mobile.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(1024, activation='relu')(x)
output = layers.Dense(NUM_CLASS, activation='softmax')(x)

# %%
model = keras.Model(mobile.input, output)

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
model.compile(optimizer=keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['acc'])

# %% [markdown]
# ## Model Training

# %%
history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1721184626.408624    7884 service.cc:146] XLA service 0x7f3c4c002e40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1721184626.408669    7884 service.cc:154]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-07-17 02:50:26.764496: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-17 02:50:28.254806: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 2024-07-17 02:50:33.435708: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng30{k2=2,k4=2,k5=0,k6=0,k7=0} for conv (f32[512,32,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:34.342306: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.906680686s
# Trying algorithm eng30{k2=2,k4=2,k5=0,k6=0,k7=0} for conv (f32[512,32,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:35.342447: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng3{k11=2} for conv (f32[512,32,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:36.350654: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.008275672s
# Trying algorithm eng3{k11=2} for conv (f32[512,32,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:37.350804: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng42{k2=1,k4=1,k5=1,k6=0,k7=0} for conv (f32[512,32,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:38.617158: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.266424801s
# Trying algorithm eng42{k2=1,k4=1,k5=1,k6=0,k7=0} for conv (f32[512,32,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:39.617303: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[512,32,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:40.516918: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.899682622s
# Trying algorithm eng4{} for conv (f32[512,32,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:41.517073: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng12{k5=1,k6=0,k7=1,k10=1} for conv (f32[512,32,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:42.943167: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.42616404s
# Trying algorithm eng12{k5=1,k6=0,k7=1,k10=1} for conv (f32[512,32,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:46.267025: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng30{k2=2,k4=2,k5=0,k6=0,k7=0} for conv (f32[512,64,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,113,113]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:47.539980: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.273025006s
# Trying algorithm eng30{k2=2,k4=2,k5=0,k6=0,k7=0} for conv (f32[512,64,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,113,113]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:48.540134: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng42{k2=1,k4=1,k5=1,k6=0,k7=0} for conv (f32[512,64,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,113,113]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:50.001229: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.46116536s
# Trying algorithm eng42{k2=1,k4=1,k5=1,k6=0,k7=0} for conv (f32[512,64,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,113,113]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:51.001370: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[512,64,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,113,113]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1721184651.252880    7884 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1721184652.202666    7884 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2024-07-17 02:50:52.729541: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.728242588s
# Trying algorithm eng4{} for conv (f32[512,64,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,113,113]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:55.228423: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng3{k11=2} for conv (f32[512,128,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,56,56]{3,2,1,0}, f32[128,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:56.161738: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.933386286s
# Trying algorithm eng3{k11=2} for conv (f32[512,128,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,56,56]{3,2,1,0}, f32[128,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:57.161878: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[512,128,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,56,56]{3,2,1,0}, f32[128,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:50:58.052642: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.890829564s
# Trying algorithm eng4{} for conv (f32[512,128,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,56,56]{3,2,1,0}, f32[128,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:01.429779: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[512,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,57,57]{3,2,1,0}, f32[128,1,3,3]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:01.689592: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.259884082s
# Trying algorithm eng4{} for conv (f32[512,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,57,57]{3,2,1,0}, f32[128,1,3,3]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1721184671.005817    7884 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1721184671.229503    7884 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2024-07-17 02:51:17.884575: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng3{k11=2} for conv (f32[512,256,29,29]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,256,31,31]{3,2,1,0}, f32[256,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:17.956600: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.072114178s
# Trying algorithm eng3{k11=2} for conv (f32[512,256,29,29]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,256,31,31]{3,2,1,0}, f32[256,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:19.931904: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng3{k11=2} for conv (f32[512,128,57,57]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,59,59]{3,2,1,0}, f32[128,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:21.001866: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.070039237s
# Trying algorithm eng3{k11=2} for conv (f32[512,128,57,57]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,59,59]{3,2,1,0}, f32[128,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:22.002015: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[512,128,57,57]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,59,59]{3,2,1,0}, f32[128,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:23.035316: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.033371076s
# Trying algorithm eng4{} for conv (f32[512,128,57,57]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,59,59]{3,2,1,0}, f32[128,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:25.694824: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng30{k2=2,k4=2,k5=0,k6=0,k7=0} for conv (f32[512,64,113,113]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,115,115]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:28.691160: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.996404744s
# Trying algorithm eng30{k2=2,k4=2,k5=0,k6=0,k7=0} for conv (f32[512,64,113,113]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,115,115]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:29.691315: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng3{k11=2} for conv (f32[512,64,113,113]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,115,115]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:32.808651: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.117408413s
# Trying algorithm eng3{k11=2} for conv (f32[512,64,113,113]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,115,115]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:33.808811: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng42{k2=1,k4=1,k5=1,k6=0,k7=0} for conv (f32[512,64,113,113]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,115,115]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:37.505296: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.696556247s
# Trying algorithm eng42{k2=1,k4=1,k5=1,k6=0,k7=0} for conv (f32[512,64,113,113]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,115,115]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:38.505444: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[512,64,113,113]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,115,115]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1721184699.410497    7884 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1721184700.845786    7884 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2024-07-17 02:51:41.699136: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.193761189s
# Trying algorithm eng4{} for conv (f32[512,64,113,113]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,115,115]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:48.937504: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=2} for conv (f32[32,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[512,32,112,112]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:49.874377: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.936945229s
# Trying algorithm eng18{k11=2} for conv (f32[32,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[512,32,112,112]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:50.874533: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng21{k2=2,k4=3,k5=0,k6=0,k7=0} for conv (f32[32,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[512,32,112,112]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:52.272111: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.397651889s
# Trying algorithm eng21{k2=2,k4=3,k5=0,k6=0,k7=0} for conv (f32[32,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[512,32,112,112]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:53.272268: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng21{k2=1,k4=3,k5=1,k6=0,k7=0} for conv (f32[32,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[512,32,112,112]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:55.067750: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.795553873s
# Trying algorithm eng21{k2=1,k4=3,k5=1,k6=0,k7=0} for conv (f32[32,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,32,112,112]{3,2,1,0}, f32[512,32,112,112]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=32, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:51:57.492985: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng21{k2=1,k4=3,k5=1,k6=0,k7=0} for conv (f32[64,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,113,113]{3,2,1,0}, f32[512,64,56,56]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:52:00.433890: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.940976695s
# Trying algorithm eng21{k2=1,k4=3,k5=1,k6=0,k7=0} for conv (f32[64,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,64,113,113]{3,2,1,0}, f32[512,64,56,56]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, feature_group_count=64, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:52:03.063798: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=2} for conv (f32[128,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,56,56]{3,2,1,0}, f32[512,128,56,56]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:52:03.988003: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.924276864s
# Trying algorithm eng18{k11=2} for conv (f32[128,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,56,56]{3,2,1,0}, f32[512,128,56,56]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:52:04.988153: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng21{k2=1,k4=3,k5=1,k6=0,k7=0} for conv (f32[128,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,56,56]{3,2,1,0}, f32[512,128,56,56]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-07-17 02:52:07.041285: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.053202695s
# Trying algorithm eng21{k2=1,k4=3,k5=1,k6=0,k7=0} for conv (f32[128,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[512,128,56,56]{3,2,1,0}, f32[512,128,56,56]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1721184735.507114    7884 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1721184735.723579    7884 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1721184743.457838    7884 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-07-17 02:52:33.467687: W external/local_tsl/tsl/framework/bfc_allocator.cc:482] Allocator (GPU_0_bfc) ran out of memory trying to allocate 10.65GiB (rounded to 11433293056)requested by op
# 2024-07-17 02:52:33.467734: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-07-17 02:52:33.467744: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 91, Chunks in use: 89. 22.8KiB allocated for chunks. 22.2KiB in use in bin. 3.7KiB client-requested in use in bin.
# 2024-07-17 02:52:33.467750: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 19, Chunks in use: 17. 10.0KiB allocated for chunks. 9.0KiB in use in bin. 8.5KiB client-requested in use in bin.
# 2024-07-17 02:52:33.467756: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 19, Chunks in use: 19. 20.2KiB allocated for chunks. 20.2KiB in use in bin. 19.1KiB client-requested in use in bin.
# 2024-07-17 02:52:33.467806: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 56, Chunks in use: 55. 121.8KiB allocated for chunks. 119.8KiB in use in bin. 112.8KiB client-requested in use in bin.
# 2024-07-17 02:52:33.467819: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 16, Chunks in use: 16. 70.2KiB allocated for chunks. 70.2KiB in use in bin. 65.0KiB client-requested in use in bin.
# 2024-07-17 02:52:33.467824: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 7, Chunks in use: 6. 69.8KiB allocated for chunks. 54.0KiB in use in bin. 47.5KiB client-requested in use in bin.
# 2024-07-17 02:52:33.467830: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 8, Chunks in use: 7. 161.5KiB allocated for chunks. 144.2KiB in use in bin. 126.0KiB client-requested in use in bin.
# 2024-07-17 02:52:33.467836: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 9, Chunks in use: 7. 353.8KiB allocated for chunks. 257.8KiB in use in bin. 236.0KiB client-requested in use in bin.
# 2024-07-17 02:52:33.467842: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 3, Chunks in use: 2. 267.0KiB allocated for chunks. 184.0KiB in use in bin. 128.0KiB client-requested in use in bin.
# 2024-07-17 02:52:33.467847: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 2, Chunks in use: 2. 296.2KiB allocated for chunks. 296.2KiB in use in bin. 256.0KiB client-requested in use in bin.
# 2024-07-17 02:52:33.467853: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 5, Chunks in use: 3. 1.55MiB allocated for chunks. 863.8KiB in use in bin. 863.6KiB client-requested in use in bin.
# 2024-07-17 02:52:33.467858: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 3, Chunks in use: 2. 1.83MiB allocated for chunks. 1.25MiB in use in bin. 1.00MiB client-requested in use in bin.
# 2024-07-17 02:52:33.467863: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 7, Chunks in use: 6. 8.77MiB allocated for chunks. 7.21MiB in use in bin. 6.00MiB client-requested in use in bin.
# 2024-07-17 02:52:33.467868: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 3, Chunks in use: 2. 7.31MiB allocated for chunks. 4.00MiB in use in bin. 4.00MiB client-requested in use in bin.
# 2024-07-17 02:52:33.467874: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks:
: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 2097152 totalling 4.00MiB
# 2024-07-17 02:52:33.469389: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4194304 totalling 4.00MiB
# 2024-07-17 02:52:33.469393: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 7035904 totalling 6.71MiB
# 2024-07-17 02:52:33.469397: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 7340032 totalling 7.00MiB
# 2024-07-17 02:52:33.469401: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 8028416 totalling 7.66MiB
# 2024-07-17 02:52:33.469406: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 308281344 totalling 294.00MiB
# 2024-07-17 02:52:33.469410: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 5419008000 totalling 5.05GiB
# 2024-07-17 02:52:33.469414: I external/local_tsl/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 5.37GiB
# 2024-07-17 02:52:33.469418: I external/local_tsl/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 14444724224 memory_limit_: 14444724224 available bytes: 0 curr_region_allocation_bytes_: 28889448448
# 2024-07-17 02:52:33.469427: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     14444724224
# InUse:                      5769045760
# MaxInUse:                  14421195008
# NumAllocs:                        2411
# MaxAllocSize:               5419008000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-07-17 02:52:33.469443: W external/local_tsl/tsl/framework/bfc_allocator.cc:494] ****************************************____________________________________________________________
# 2024-07-17 02:52:33.469675: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 11433293008 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(x_test, y_test))
#
# File ~/anaconda3/envs/health_care/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/anaconda3/envs/health_care/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# RuntimeError: pybind11::error_already_set: MISMATCH of original and normalized active exception types: ORIGINAL ResourceExhaustedError REPLACED BY KeyboardInterrupt: <EMPTY MESSAGE>
#
# At:
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/tensorflow/python/framework/errors_impl.py(377): __init__
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/tensorflow/python/eager/execute.py(53): quick_execute
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/tensorflow/python/eager/context.py(1552): call_function
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py(251): call_flat
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py(216): call_preflattened
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py(1322): _call_flat
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py(919): _call
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py(833): __call__
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py(150): error_handler
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py(318): fit
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py(117): error_handler
#   /tmp/ipykernel_6834/3927297201.py(1): <module>
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3577): run_code
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3517): run_ast_nodes
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3334): run_cell_async
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/IPython/core/async_helpers.py(128): _pseudo_sync_runner
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3130): _run_cell
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3075): run_cell
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/ipykernel/zmqshell.py(549): run_cell
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/ipykernel/ipkernel.py(449): do_execute
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/ipykernel/kernelbase.py(778): execute_request
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/ipykernel/ipkernel.py(362): execute_request
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/ipykernel/kernelbase.py(437): dispatch_shell
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/ipykernel/kernelbase.py(534): process_one
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/ipykernel/kernelbase.py(545): dispatch_queue
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/asyncio/events.py(80): _run
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/asyncio/base_events.py(1909): _run_once
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/asyncio/base_events.py(603): run_forever
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/tornado/platform/asyncio.py(205): start
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/ipykernel/kernelapp.py(739): start
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/traitlets/config/application.py(1075): launch_instance
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/site-packages/ipykernel_launcher.py(18): <module>
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/runpy.py(86): _run_code
#   /home/ec2-user/anaconda3/envs/health_care/lib/python3.10/runpy.py(196): _run_module_as_main

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test-Loss: {test_loss}, Test-Acc: {test_acc}')

# %%
with open('README.md', 'a') as file:
    file.write('# Results\n')

    file.write('## Loss\n')
    file.write(f'- Train Loss: {history.history["loss"][-1]:.4f}\n')
    file.write(f'- Test Loss: {test_loss:.4f}\n\n')

    file.write('### Loss Graph\n')
    file.write('![](Loss_Result.png)\n\n')

    file.write('## Accuracy\n')
    file.write(f'- Train Accuracy: {history.history["acc"][-1] * 100:.2f}%\n')
    file.write(f'- Test Accuracy: {test_acc * 100:.2f}%\n')

    file.write('### Accuracy Graph\n')
    file.write('![](Accuracy_Result.png)\n\n')

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legen(['Acc', 'Val Acc'])
plt.title(f'Korean Food Classification {EXPERIMENT_DATA["number"]}(Acc)')

plt.savefig('Accuracy_Result.png')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legen(['Loss', 'Val Loss'])
plt.title(f'Korean Food Classification {EXPERIMENT_DATA["number"]}(Loss)')

plt.savefig('Loss_Result.png')
plt.show()
